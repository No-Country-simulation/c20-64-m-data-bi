# %% [markdown]
# ### Importar Librerías

# %%
# Importar pandas
import pandas as pd

# importar numpy
import numpy as np

# Importar Matplotlib
import matplotlib.pyplot as plt

# Importar Seaborn
import seaborn as sns

# %% [markdown]
# ### Cargar Datos

# %% [markdown]
# Datos históricos de la Producción Agricola en Chiapas

# %%
# Cargar datos
cierre_agricola = pd.read_csv('C:/Users/HP VICTUS/c20-64-m-data-bi/DataSets/cierre_agricola_chiapas.csv', encoding='utf-8-sig')
cierre_agricola= cierre_agricola.rename(columns={'Anio': 'Año'})
cierre_agricola.head()
# Out:
#     Año  Idestado Nomestado  Idddr            Nomddr  Idcader  \
# 0  2003         7   Chiapas     18  Tuxtla Gutiérrez        1
# 1  2003         7   Chiapas     18  Tuxtla Gutiérrez        1
# 2  2003         7   Chiapas     18  Tuxtla Gutiérrez        1
# 3  2003         7   Chiapas     18  Tuxtla Gutiérrez        1
# 4  2003         7   Chiapas     18  Tuxtla Gutiérrez        1
#
#            Nomcader  Idmunicipio Nommunicipio  Idciclo  ... Nomunidad  \
# 0  Tuxtla Gutiérrez            2        Acala        1  ...  Tonelada
# 1  Tuxtla Gutiérrez            2        Acala        1  ...  Tonelada
# 2  Tuxtla Gutiérrez            2        Acala        1  ...  Tonelada
# 3  Tuxtla Gutiérrez            2        Acala        2  ...  Tonelada
# 4  Tuxtla Gutiérrez            2        Acala        2  ...  Tonelada
#
#    Idcultivo   Nomcultivo  Sembrada Cosechada  Siniestrada Volumenproduccion  \
# 0    7490000   Maíz grano     286.0     286.0          0.0             715.0
# ...

# %% [markdown]
# Datos de los Municipios de Chiapas

# %%
df1 = pd.read_csv('C:/Users/HP VICTUS/c20-64-m-data-bi/DataSets/Municipios .csv', encoding='utf-8-sig')
df1.head()
# Out:
#    FID   municipio  cvemun Codigo_Region              REGION_2    Latitud  \
# 0    0  Acacoyagua       1              X          X Soconusco  15.414140
# 1    1       Acala       2             IV     IV De Los Llanos  16.551605
# 2    2  Acapetahua       3              X          X Soconusco  15.233286
# 3    3  Altamirano       4            XII  XII Selva Lacandona  16.661885
# 4    4      Amatán       5           VIII           VIII Norte  17.385594
#
#     Longitud       sup  pobtotal
# 0 -92.681685  247.8485     17994
# 1 -92.814657  304.3286     21187
# 2 -92.772723  543.0506     26899
# 3 -91.862573  954.6929     36160
# 4 -92.857338  315.6799     24512

# %% [markdown]
# Datos de la precipitación en Chiapas

# %%
df2 = pd.read_csv('C:/Users/HP VICTUS/c20-64-m-data-bi/DataSets/PP_Chiapas.csv', encoding='utf-8-sig')
df2.head()
# Out:
#    ID_Año   Año  ID_Estado   Estado  Enero  Febrero  Marzo  Abril   Mayo  \
# 0     1.0  2003          7  Chiapas   23.9     13.5   35.6   26.5  145.4
# 1     2.0  2004          7  Chiapas   45.7     42.3   31.1   42.8  193.8
# 2     3.0  2005          7  Chiapas    8.5     19.7   33.8   47.4  158.4
# 3     4.0  2006          7  Chiapas   78.4     47.3   32.2   49.2  229.7
# 4     5.0  2007          7  Chiapas  104.0     31.6   33.4   58.5  148.0
#
#    Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre   Anual
# 0  314.6  232.9   309.8       371.5    253.4      155.4       53.1  1935.6
# 1  250.2  249.1   195.7       310.8    235.2       69.1       48.0  1713.8
# 2  413.4  350.8   338.9       362.7    315.0       56.8       85.3  2190.7
# 3  447.0  356.7   285.1       339.4    323.5       94.4       71.3  2354.2
# 4  256.6  279.3   459.1       368.3    503.2       41.4       19.2  2302.6

# %%
df2['PP_Anual']= df2[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre']].mean(axis=1).round(2)
df2.head()
# Out:
#    ID_Año   Año  ID_Estado   Estado  Enero  Febrero  Marzo  Abril   Mayo  \
# 0     1.0  2003          7  Chiapas   23.9     13.5   35.6   26.5  145.4
# 1     2.0  2004          7  Chiapas   45.7     42.3   31.1   42.8  193.8
# 2     3.0  2005          7  Chiapas    8.5     19.7   33.8   47.4  158.4
# 3     4.0  2006          7  Chiapas   78.4     47.3   32.2   49.2  229.7
# 4     5.0  2007          7  Chiapas  104.0     31.6   33.4   58.5  148.0
#
#    Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre   Anual  \
# 0  314.6  232.9   309.8       371.5    253.4      155.4       53.1  1935.6
# 1  250.2  249.1   195.7       310.8    235.2       69.1       48.0  1713.8
# 2  413.4  350.8   338.9       362.7    315.0       56.8       85.3  2190.7
# 3  447.0  356.7   285.1       339.4    323.5       94.4       71.3  2354.2
# 4  256.6  279.3   459.1       368.3    503.2       41.4       19.2  2302.6
#
#    PP_Anual
# 0    161.30
# 1    142.82
# 2    182.56
# 3    196.18
# ...

# %%
# Selección de dos columnas del DataFrame
Promedio_Precip_Anual= df2[['Año', 'PP_Anual']]
print(Promedio_Precip_Anual)
# Out:
#      Año  PP_Anual
# 0   2003    161.30
# 1   2004    142.82
# 2   2005    182.56
# 3   2006    196.18
# 4   2007    191.88
# 5   2008    196.24
# 6   2009    162.76
# 7   2010    227.52
# 8   2011    198.47
# 9   2012    157.11
# 10  2013    189.90
# 11  2014    171.35
# 12  2015    145.09
# 13  2016    134.52
# 14  2017    166.17
# 15  2018    142.10
# 16  2019    147.29
# 17  2020    180.66
# 18  2021    150.60
# 19  2022    171.18
# 20  2023    141.79

# %% [markdown]
# Datos de Temperatura en Chiapas

# %%
df3 = pd.read_csv('C:/Users/HP VICTUS/c20-64-m-data-bi/DataSets/Prom_Temperatura_Chiapas.csv', encoding='utf-8-sig')
df3.head()
# Out:
#    ID_Año   Año  ID_Estado   Estado  Enero  Febrero  Marzo  Abril  Mayo  \
# 0       1  2004          1  Chiapas   21.9     23.0   24.7   25.3  25.3
# 1       2  2005          1  Chiapas   23.0     23.5   25.0   26.3  26.3
# 2       3  2006          1  Chiapas   23.7     24.1   25.2   27.3  27.5
# 3       4  2007          1  Chiapas   23.1     24.3   25.1   27.1  27.6
# 4       5  2008          1  Chiapas   22.5     23.6   24.2   26.4  26.8
#
#    Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre  Anual
# 0   24.9   24.5    24.7        24.4     23.8       22.8       22.4   24.0
# 1   25.5   25.3    25.4        25.3     24.7       23.3       23.0   24.7
# 2   26.3   26.3    26.2        26.1     25.4       24.0       23.3   25.4
# 3   25.8   25.5    25.8        25.5     24.3       23.2       22.4   25.0
# 4   25.5   24.6    25.8        25.7     24.6       22.8       22.0   24.5

# %%
# Selección de dos columnas del DataFrame
Promedio_temperatura_anual= df3[['Año', 'Anual']]
print(Promedio_temperatura_anual)
# Out:
#      Año   Anual
# 0   2004    24.0
# 1   2005    24.7
# 2   2006    25.4
# 3   2007    25.0
# 4   2008    24.5
# 5   2009    24.4
# 6   2010    24.3
# 7   2011    24.3
# 8   2012    24.6
# 9   2013  2278.9
# 10  2014  2056.1
# 11  2015  1741.1
# 12  2016  1614.2
# 13  2017  1994.0
# 14  2018  1705.3
# 15  2019  1767.4
# 16  2020  2167.9
# 17  2021  1807.2
# 18  2022  2054.0

# %% [markdown]
# Datos de Suelos en Chiapas

# %%
df4 = pd.read_csv('C:/Users/HP VICTUS/c20-64-m-data-bi/DataSets/Suelos_Chiapas.csv', encoding='utf-8-sig')
df4.head()
# Out:
#    FID  Shape *   municipio  cvemun     REGION_2      N_G1    Area_Km2
# 0    0  Polygon  Acacoyagua       1  X Soconusco  CAMBISOL   27.486114
# 1    1  Polygon  Acacoyagua       1  X Soconusco  FLUVISOL    0.017437
# 2    2  Polygon  Acacoyagua       1  X Soconusco  LEPTOSOL  132.958343
# 3    3  Polygon  Acacoyagua       1  X Soconusco  PHAEOZEM   83.261034
# 4    4  Polygon  Acacoyagua       1  X Soconusco   REGOSOL    4.125552

# %% [markdown]
# ### Total de la Producción Anual

# %%
total_produccion_anual = cierre_agricola.groupby('Año')['Volumenproduccion'].sum().reset_index()
print(total_produccion_anual)
# Out:
#      Año  Volumenproduccion
# 0   2003        13138399.43
# 1   2004        14182363.44
# 2   2005        11952320.99
# 3   2006        12527312.19
# 4   2007        12212605.29
# 5   2008        12065054.48
# 6   2009        11601751.35
# 7   2010        11690417.98
# 8   2011        12323396.26
# 9   2012        11907239.88
# 10  2013        10776210.31
# 11  2014        10194148.05
# 12  2015        10038650.59
# 13  2016        10480361.75
# 14  2017         9239700.38
# 15  2018         8621551.31
# 16  2019         8783440.86
# 17  2020         6414344.63
# 18  2021         6180038.74
# 19  2022         9577149.68
# 20  2023         9331138.67

# %% [markdown]
# ### Promedio de la Producción Anual

# %%
Promedio_Producción_Anual = cierre_agricola.groupby('Año')['Volumenproduccion'].mean().reset_index()
print(Promedio_Producción_Anual)
# Out:
#      Año  Volumenproduccion
# 0   2003       13151.550981
# 1   2004       13931.594735
# 2   2005       11976.273537
# 3   2006       12796.028795
# 4   2007       11822.463979
# 5   2008       11702.283686
# 6   2009       11340.910411
# 7   2010       11529.011815
# 8   2011       11929.715644
# 9   2012       11329.438516
# 10  2013        9996.484518
# 11  2014        9378.241076
# 12  2015        9151.003273
# 13  2016        9433.268902
# 14  2017        8324.054396
# 15  2018        7774.167096
# 16  2019        7970.454501
# 17  2020        6709.565513
# 18  2021        6286.916317
# 19  2022        8386.295692
# 20  2023        8156.589747

# %% [markdown]
# ### Evolución Anual de Producción Agrícola, Temperatura y Precipitación

# %%
años = list(range(2003, 2024))

# %%
print(f"Longitud de años: {len(años)}")
print(f"Longitud de Promedio_Producción_Anual: {len(Promedio_Producción_Anual)}")
print(f"Longitud de Promedio_temperatura_anual: {len(Promedio_temperatura_anual)}")
print(f"Longitud de Promedio_Precip_Anual: {len(Promedio_Precip_Anual)}")
# Out:
# Longitud de años: 21
# Longitud de Promedio_Producción_Anual: 21
# Longitud de Promedio_temperatura_anual: 19
# Longitud de Promedio_Precip_Anual: 21

# %%
# Si las longitudes no coinciden, ajusta los datos
# Ejemplo: Ajustar todas las listas a la longitud de 'años'
min_length = min(len(años), len(Promedio_Producción_Anual), len(Promedio_temperatura_anual), len(Promedio_Precip_Anual))

años = años[:min_length]
Promedio_Producción_Anual = Promedio_Producción_Anual[:min_length]
Promedio_temperatura_anual = Promedio_temperatura_anual[:min_length]
Promedio_Precip_Anual = Promedio_Precip_Anual[:min_length]

# %%
plt.figure(figsize=(12, 8))
plt.plot(años, Promedio_Producción_Anual, label='Producción Agrícola', marker='o')
plt.plot(años, Promedio_temperatura_anual, label='Temperatura', marker='o')
plt.plot(años, Promedio_Precip_Anual, label='Precipitación', marker='o')

plt.xlabel('Año')
plt.ylabel('Valor')
plt.title('Evolución Anual de Producción Agrícola, Temperatura y Precipitación')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Relación entre Precipitación, Temperatura y Producción Agrícola

# %%
#Combinación de las tablas
df_combinadas = pd.merge(Promedio_Precip_Anual, Promedio_temperatura_anual, on='Año')
df_combinadas = pd.merge(df_combinadas,Promedio_Producción_Anual , on='Año')
print(df_combinadas)
# Out:
#      Año  PP_Anual   Anual  Volumenproduccion
# 0   2004    142.82    24.0       13931.594735
# 1   2005    182.56    24.7       11976.273537
# 2   2006    196.18    25.4       12796.028795
# 3   2007    191.88    25.0       11822.463979
# 4   2008    196.24    24.5       11702.283686
# 5   2009    162.76    24.4       11340.910411
# 6   2010    227.52    24.3       11529.011815
# 7   2011    198.47    24.3       11929.715644
# 8   2012    157.11    24.6       11329.438516
# 9   2013    189.90  2278.9        9996.484518
# 10  2014    171.35  2056.1        9378.241076
# 11  2015    145.09  1741.1        9151.003273
# 12  2016    134.52  1614.2        9433.268902
# 13  2017    166.17  1994.0        8324.054396
# 14  2018    142.10  1705.3        7774.167096
# 15  2019    147.29  1767.4        7970.454501
# 16  2020    180.66  2167.9        6709.565513
# 17  2021    150.60  1807.2        6286.916317

# %% [markdown]
# Resultado: El resultado es una nueva tabla (DataFrame) que muestra los coeficientes de correlación de Pearson entre cada par de columnas.
#
# Los valores oscilan entre -1 y 1:
#
# 1: correlación positiva perfecta.
#
# 0: sin correlación.
#
# -1: correlación negativa perfecta.

# %%
# Calcular la matriz de correlación
correlation_matrix = df_combinadas.corr()
print(correlation_matrix)
# Out:
#                         Año  PP_Anual     Anual  Volumenproduccion
# Año                1.000000 -0.432389  0.840282          -0.965350
# PP_Anual          -0.432389  1.000000 -0.420334           0.401123
# Anual              0.840282 -0.420334  1.000000          -0.858161
# Volumenproduccion -0.965350  0.401123 -0.858161           1.000000

# %%
# Gráfico de dispersión
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df_combinadas, x='PP_Anual', y='Anual', hue='Volumenproduccion')
sns.regplot(data=df_combinadas, x='PP_Anual', y='Anual', scatter=False, color='black', line_kws={'label': 'Línea de Tendencia'})
for i in range(len(df_combinadas)):
    plt.text(df_combinadas['PP_Anual'][i], df_combinadas['Anual'][i], str(df_combinadas['Año'][i]), fontsize=10, ha='right')
plt.xlabel('Precipitación(mm)')
plt.ylabel('Temperatura (°C)')
plt.title('Relación entre Precipitación, Temperatura y Producción Agrícola')
plt.legend(title='Producción Agrícola')
plt.grid(True)
plt.show()

# %%
# Selecciono solo las dos columnas
df_seleccionado = df_combinadas[['Volumenproduccion', 'Anual']]

# Calcula la correlación
correlacion = df_seleccionado.corr()

print(correlacion)
# Out:
#                    Volumenproduccion     Anual
# Volumenproduccion           1.000000 -0.858161
# Anual                      -0.858161  1.000000

# %% [markdown]
# Analisis: Según la interpretación del analisis de correlación de pearson, existe una correlacion negativa moderada o inversa, hay una tendencia general en los datos, es decir que a medida que la temperatura aumenta la producción tiende a disminuir.

# %%
# Gráfico de dispersión Producción vs Temperatura
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df_combinadas, x='Anual', y='Volumenproduccion', hue='Volumenproduccion')
sns.regplot(data=df_combinadas, x='Anual', y='Volumenproduccion', scatter=False, color='black', line_kws={'label': 'Línea de Tendencia'})
plt.ylabel('Producción Agrícola')
plt.title('Relación entre Temperatura y Producción Agrícola')
plt.legend(title='Producción Agrícola')
plt.grid(True)
plt.show()

# %%
# Selecciono solo las dos columnas-Precipitación
df_seleccionado = df_combinadas[['Volumenproduccion', 'PP_Anual']]

# Calcula la correlación
correlacion = df_seleccionado.corr()

print(correlacion)
# Out:
#                    Volumenproduccion  PP_Anual
# Volumenproduccion           1.000000  0.401123
# PP_Anual                    0.401123  1.000000

# %% [markdown]
# Hay una relación positiva entre las dos variables. Esto significa que, en general, a medida que una variable aumenta, la otra también tiende a aumentar. Sin embargo, esta relación es débil, aunque existe una tendencia observable , hay mucha variabilidad en los datos, lo que significa que no se puede predecir con precisión el comportamiento de una variable basándose en la otra.
# Ambas tienden a aumentar juntas, pero la relación no es lo suficientemente fuerte como para hacer predicciones fiables.

# %%
# Gráfico de dispersión Producción vs precipitación
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df_combinadas, x='PP_Anual', y='Volumenproduccion', hue='Volumenproduccion')
sns.regplot(data=df_combinadas, x='PP_Anual', y='Volumenproduccion', scatter=False, color='black', line_kws={'label': 'Línea de Tendencia'})
plt.ylabel('Producción Agrícola')
plt.title('Relación entre Precipitación y Producción Agrícola')
plt.legend(title='Producción Agrícola')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Gráficos de volumen de producción total, a nivel de superficie sembrada y cosechada.

# %%
agrupado = cierre_agricola.groupby('Año').agg({
    'Sembrada': 'sum',
    'Cosechada': 'sum',
    'Volumenproduccion': 'sum',
    
}).reset_index()

# %%
# Paso 2: Graficar la superficie sembrada y cosechada junto con el volumen de producción

# Graficar superficie sembrada y cosechada
plt.figure(figsize=(14, 7))
plt.plot(agrupado['Año'], agrupado['Sembrada'], label='Superficie Sembrada (ha)', marker='o')
plt.plot(agrupado['Año'], agrupado['Cosechada'], label='Superficie Cosechada (ha)', marker='o')

plt.title('Superficie Sembrada y Cosechada por Año')
plt.xlabel('Año')
plt.ylabel('Hectáreas')
plt.legend()
plt.grid(True)
plt.show()

# Graficar volumen de producción
plt.figure(figsize=(14, 7))
plt.plot(agrupado['Año'], agrupado['Volumenproduccion'], label='Volumen de Producción (ton)', color='green', marker='o')

plt.title('Volumen de Producción por Año')
plt.xlabel('Año')
plt.ylabel('Volumen de Producción (ton)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Determinar cuales son los cultivos más importantes en cuanto a volumen y valor económico.

# %%
# Paso 1: Agrupar los datos por cultivo y sumar el volumen y valor de producción
agrupado_cultivos = cierre_agricola.groupby('Nomcultivo').agg({
    'Volumenproduccion': 'sum',
    'Valorproduccion': 'sum'
}).reset_index()

# Paso 2: Ordenar por volumen de producción y por valor económico
cultivos_mas_importantes_volumen = agrupado_cultivos.sort_values(by='Volumenproduccion', ascending=False)
cultivos_mas_importantes_valor = agrupado_cultivos.sort_values(by='Valorproduccion', ascending=False)

# Paso 3: Seleccionar los 5 cultivos principales (o los que te interesen)
top_5_cultivos_volumen = cultivos_mas_importantes_volumen.head(5)
top_5_cultivos_valor = cultivos_mas_importantes_valor.head(5)

# Mostrar los resultados
print("Top 5 cultivos por volumen de producción:")
print(top_5_cultivos_volumen)

print("\nTop 5 cultivos por valor económico:")
print(top_5_cultivos_valor)
# Out:
# Top 5 cultivos por volumen de producción:
#            Nomcultivo  Volumenproduccion  Valorproduccion
# 47  Pastos y praderas        86972746.45     4.464429e+10
# 8      Caña de azúcar        57995654.72     3.491776e+10
# 38         Maíz grano        29115043.16     9.564906e+10
# 54            Plátano        15115346.07     3.479571e+10
# 5         Café cereza         9925908.58     4.218504e+10
#
# Top 5 cultivos por valor económico:
#            Nomcultivo  Volumenproduccion  Valorproduccion
# 38         Maíz grano        29115043.16     9.564906e+10
# 47  Pastos y praderas        86972746.45     4.464429e+10
# 5         Café cereza         9925908.58     4.218504e+10
# 8      Caña de azúcar        57995654.72     3.491776e+10
# 54            Plátano        15115346.07     3.479571e+10

# %%
# Graficar los cultivos más importantes por volumen
plt.figure(figsize=(10, 6))
plt.bar(top_5_cultivos_volumen['Nomcultivo'], top_5_cultivos_volumen['Volumenproduccion'], color='blue')
plt.title('Top 5 Cultivos por Volumen de Producción')
plt.xlabel('Cultivo')
plt.ylabel('Volumen de Producción (ton)')
plt.xticks(rotation=45)
plt.show()

# Graficar los cultivos más importantes por valor
plt.figure(figsize=(10, 6))
plt.bar(top_5_cultivos_valor['Nomcultivo'], top_5_cultivos_valor['Valorproduccion'], color='green')
plt.title('Top 5 Cultivos por Valor Económico')
plt.xlabel('Cultivo')
plt.ylabel('Valor de Producción (pesos)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## TENDENCIAS A LO LARGO DEL TIEMPO

# %%
# Paso 1: Agrupar los datos por año y cultivo, sumando el volumen y valor de producción
agrupado = cierre_agricola.groupby(['Año', 'Nomcultivo']).agg({
    'Volumenproduccion': 'sum',
    'Valorproduccion': 'sum'
}).reset_index()

# Paso 2: Filtrar los cultivos más importantes (opcional)
# Puedes hacer un análisis general o enfocarte en los cultivos más importantes
cultivos_importantes = agrupado.groupby('Nomcultivo')['Volumenproduccion'].sum().nlargest(5).index
agrupado_filtrado = agrupado[agrupado['Nomcultivo'].isin(cultivos_importantes)]

# Paso 3: Graficar la tendencia de volumen de producción a lo largo del tiempo
plt.figure(figsize=(14, 7))
for cultivo in cultivos_importantes:
    cultivo_data = agrupado_filtrado[agrupado_filtrado['Nomcultivo'] == cultivo]
    plt.plot(cultivo_data['Año'], cultivo_data['Volumenproduccion'], label=cultivo)

plt.title('Tendencia del Volumen de Producción por Cultivo (2003-2023)')
plt.xlabel('Año')
plt.ylabel('Volumen de Producción (ton)')
plt.legend()
plt.grid(True)
plt.show()

# Paso 4: Graficar la tendencia de valor de producción a lo largo del tiempo
plt.figure(figsize=(14, 7))
for cultivo in cultivos_importantes:
    cultivo_data = agrupado_filtrado[agrupado_filtrado['Nomcultivo'] == cultivo]
    plt.plot(cultivo_data['Año'], cultivo_data['Valorproduccion'], label=cultivo)

plt.title('Tendencia del Valor de Producción por Cultivo (2003-2023)')
plt.xlabel('Año')
plt.ylabel('Valor de Producción (pesos)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Paso 2: Filtrar los cultivos más importantes (opcional)
# Puedes hacer un análisis general o enfocarte en los cultivos más importantes
cultivos_importantes = agrupado.groupby('Nomcultivo')['Volumenproduccion'].sum().nlargest(10).index
agrupado_filtrado = agrupado[agrupado['Nomcultivo'].isin(cultivos_importantes)]

# Paso 3: Graficar la tendencia de volumen de producción a lo largo del tiempo
plt.figure(figsize=(14, 7))
for cultivo in cultivos_importantes:
    cultivo_data = agrupado_filtrado[agrupado_filtrado['Nomcultivo'] == cultivo]
    plt.plot(cultivo_data['Año'], cultivo_data['Volumenproduccion'], label=cultivo)

plt.title('Tendencia del Volumen de Producción por Cultivo (2003-2023)')
plt.xlabel('Año')
plt.ylabel('Volumen de Producción (ton)')
plt.legend()
plt.grid(True)
plt.show()

# Paso 4: Graficar la tendencia de valor de producción a lo largo del tiempo
plt.figure(figsize=(14, 7))
for cultivo in cultivos_importantes:
    cultivo_data = agrupado_filtrado[agrupado_filtrado['Nomcultivo'] == cultivo]
    plt.plot(cultivo_data['Año'], cultivo_data['Valorproduccion'], label=cultivo)

plt.title('Tendencia del Valor de Producción por Cultivo (2003-2023)')
plt.xlabel('Año')
plt.ylabel('Valor de Producción (pesos)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## GEOGRÁFICAMENTE

# %%
# Agrupar los datos por año y municipio
produccion_por_ano_municipio = cierre_agricola.groupby(['Año', 'Nommunicipio']).agg({
    'Volumenproduccion': 'sum',
    'Valorproduccion': 'sum',
    'Sembrada': 'sum',
    'Cosechada': 'sum'
}).reset_index()

produccion_por_ano_municipio.head()
# Out:
#     Año               Nommunicipio  Volumenproduccion  Valorproduccion  \
# 0  2003                 Acacoyagua          130698.68     1.208423e+08
# 1  2003                      Acala           60529.50     8.711058e+07
# 2  2003                 Acapetahua         1125195.91     8.446582e+08
# 3  2003                 Altamirano           13910.69     3.027777e+07
# 4  2003  Amatenango de La Frontera           38273.61     8.584591e+07
#
#    Sembrada  Cosechada
# 0    9517.5     9283.0
# 1   20675.0    20675.0
# 2   38394.0    37166.0
# 3    8752.0     8752.0
# 4   13494.0    13488.0

# %%
# Filtrar los top 5 municipios por año según el volumen de producción
top_municipios_por_ano = produccion_por_ano_municipio.groupby('Año').apply(
    lambda x: x.nlargest(5, 'Volumenproduccion')
).reset_index(drop=True)

# Filtrar los top 5 municipios por año según el valor de producción
top_municipios_valor_por_ano = produccion_por_ano_municipio.groupby('Año').apply(
    lambda x: x.nlargest(5, 'Valorproduccion')
).reset_index(drop=True)

# %%
# Visualizar volumen de producción para los principales municipios en el tiempo
plt.figure(figsize=(14, 7))
for municipio in top_municipios_por_ano['Nommunicipio'].unique():
    data_municipio = top_municipios_por_ano[top_municipios_por_ano['Nommunicipio'] == municipio]
    plt.plot(data_municipio['Año'], data_municipio['Volumenproduccion'], marker='o', label=municipio)

plt.title('Volumen de Producción por Municipio (Top 5 por Año)')
plt.xlabel('Año')
plt.ylabel('Volumen de Producción (ton)')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# Visualizar valor de producción para los principales municipios en el tiempo
plt.figure(figsize=(14, 7))
for municipio in top_municipios_valor_por_ano['Nommunicipio'].unique():
    data_municipio = top_municipios_valor_por_ano[top_municipios_valor_por_ano['Nommunicipio'] == municipio]
    plt.plot(data_municipio['Año'], data_municipio['Valorproduccion'], marker='o', label=municipio)

plt.title('Valor de Producción por Municipio (Top 5 por Año)')
plt.xlabel('Año')
plt.ylabel('Valor de Producción (pesos)')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# ## CICLO PRODUCTIVO Y MODALIDAD

# %%
# Agrupar los datos por ciclo productivo y modalidad
produccion_por_ciclo_y_modalidad = cierre_agricola.groupby(['Nomcicloproductivo', 'Nommodalidad']).agg({
    'Volumenproduccion': 'sum',
    'Valorproduccion': 'sum'
}).reset_index()

# %%
# Gráfico de barras para comparar los volúmenes de producción por ciclo agrícola
plt.figure(figsize=(14, 7))
for modalidad in produccion_por_ciclo_y_modalidad['Nommodalidad'].unique():
    modalidad_data = produccion_por_ciclo_y_modalidad[produccion_por_ciclo_y_modalidad['Nommodalidad'] == modalidad]
    plt.bar(modalidad_data['Nomcicloproductivo'], modalidad_data['Volumenproduccion'], label=modalidad)

plt.title('Volumen de Producción por Ciclo Agrícola y Modalidad')
plt.xlabel('Ciclo Productivo')
plt.ylabel('Volumen de Producción (ton)')
plt.legend(title="Modalidad")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
cierre_agricola.Nommodalidad.value_counts()
# Out:
# Nommodalidad
# Temporal    19518
# Riego        2580
# Name: count, dtype: int64

# %%
# Ordenar por volumen de producción para ver cuáles son los ciclos más productivos
ciclos_mas_productivos = produccion_por_ciclo_y_modalidad.sort_values(by='Volumenproduccion', ascending=False)
print("Ciclos productivos y modalidades más productivos:")
print(ciclos_mas_productivos.head(10))
# Out:
# Ciclos productivos y modalidades más productivos:
#   Nomcicloproductivo Nommodalidad  Volumenproduccion  Valorproduccion
# 3           Perennes     Temporal       1.388219e+08     1.605873e+11
# 2           Perennes        Riego       4.852781e+07     5.626636e+10
# 5   Primavera-Verano     Temporal       2.875059e+07     1.059272e+11
# 1     Otoño-Invierno     Temporal       4.621717e+06     2.105328e+10
# 0     Otoño-Invierno        Riego       1.954100e+06     9.145307e+09
# 4   Primavera-Verano        Riego       5.615262e+05     3.512485e+09

# %%
# Agrupar los datos por año, ciclo productivo y modalidad
produccion_anual_por_ciclo_y_modalidad = cierre_agricola.groupby(['Año', 'Nomcicloproductivo', 'Nommodalidad']).agg({
    'Volumenproduccion': 'sum',
    'Valorproduccion': 'sum'
}).reset_index()

# Graficar la tendencia a lo largo del tiempo para cada ciclo productivo y modalidad
plt.figure(figsize=(14, 7))
for ciclo in produccion_anual_por_ciclo_y_modalidad['Nomcicloproductivo'].unique():
    for modalidad in produccion_anual_por_ciclo_y_modalidad['Nommodalidad'].unique():
        data_ciclo_modalidad = produccion_anual_por_ciclo_y_modalidad[
            (produccion_anual_por_ciclo_y_modalidad['Nomcicloproductivo'] == ciclo) &
            (produccion_anual_por_ciclo_y_modalidad['Nommodalidad'] == modalidad)]
        plt.plot(data_ciclo_modalidad['Año'], data_ciclo_modalidad['Volumenproduccion'], marker='o', 
                 label=f"{ciclo} - {modalidad}")

plt.title('Tendencias del Volumen de Producción por Ciclo Agrícola y Modalidad (2003-2023)')
plt.xlabel('Año')
plt.ylabel('Volumen de Producción (ton)')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Cultivos con mejor rendimiento

# %%
# Agrupar los datos por cultivo y año para calcular el rendimiento promedio
rendimiento_por_cultivo_ano = cierre_agricola.groupby(['Nomcultivo', 'Año']).agg({
    'Rendimiento': 'mean'
}).reset_index()
rendimiento_por_cultivo_ano
# Out:
#      Nomcultivo   Año  Rendimiento
# 0      Aguacate  2003     4.812727
# 1      Aguacate  2004     5.018182
# 2      Aguacate  2005     4.345000
# 3      Aguacate  2006     4.817391
# 4      Aguacate  2007     4.818261
# ...         ...   ...          ...
# 1174  Zarzamora  2004     0.700000
# 1175  Zarzamora  2005     0.700000
# 1176  Zarzamora  2006     0.750000
# 1177  Zarzamora  2007     1.000000
# 1178  Zarzamora  2008     1.000000
#
# [1179 rows x 3 columns]

# %%
# Calcular el rendimiento promedio por cultivo a lo largo de todos los años
rendimiento_promedio_cultivo = rendimiento_por_cultivo_ano.groupby('Nomcultivo').agg({
    'Rendimiento': 'mean'
}).reset_index()

# Ordenar los cultivos por rendimiento promedio
cultivos_mayor_rendimiento = rendimiento_promedio_cultivo.sort_values(by='Rendimiento', ascending=False)

# Mostrar los cultivos con mayor rendimiento promedio
print("Cultivos con mayor rendimiento promedio:")
print(cultivos_mayor_rendimiento.head(10))
# Out:
# Cultivos con mayor rendimiento promedio:
#                    Nomcultivo  Rendimiento
# 17        Crisantemo (gruesa)  2864.840000
# 27            Lilium (gruesa)  2159.750000
# 43              Palma camedor   472.591667
# 44     Palma camedor (gruesa)   463.117500
# 57  Semilla de caña de azúcar    95.066250
# 8              Caña de azúcar    86.917362
# 46                     Papaya    70.482473
# 9   Caña de azúcar piloncillo    39.132857
# 67     Tomate rojo (jitomate)    36.227285
# 52                       Piña    34.009048

# %%
# Filtrar los cultivos más productivos (por rendimiento) para su análisis a lo largo del tiempo
cultivos_top = cultivos_mayor_rendimiento.head(5)['Nomcultivo']

# Graficar la tendencia del rendimiento a lo largo del tiempo para los cultivos más productivos
plt.figure(figsize=(14, 7))
for cultivo in cultivos_top:
    data_cultivo = rendimiento_por_cultivo_ano[rendimiento_por_cultivo_ano['Nomcultivo'] == cultivo]
    plt.plot(data_cultivo['Año'], data_cultivo['Rendimiento'], marker='o', label=cultivo)

plt.title('Tendencia de Rendimiento por Cultivo (2003-2023)')
plt.xlabel('Año')
plt.ylabel('Rendimiento (ton/ha)')
plt.legend(title="Cultivo")
plt.grid(True)
plt.show()

# %%
cierre_agricola.loc[:, ["Nomcultivo", "Rendimiento"]]
# Out:
#         Nomcultivo  Rendimiento
# 0       Maíz grano         2.50
# 1           Sandía        18.00
# 2      Sorgo grano         3.00
# 3        Cacahuate         1.57
# 4       Maíz grano         2.66
# ...            ...          ...
# 22093       Frijol         0.70
# 22094   Maíz grano         0.88
# 22095       Frijol         0.75
# 22096   Maíz grano         1.14
# 22097  Café cereza         1.50
#
# [22098 rows x 2 columns]

# %%
# Definir la lista de cultivos de interés
cultivos_interes = [
    "Crisantemo (gruesa)",
    "Lilium (gruesa)",
    "Palma camedor",
    "Palma camedor (gruesa)",
    "Semilla de caña de azúcar",
    "Caña de azúcar",
    "Papaya",
    "Caña de azúcar piloncillo",
    "Tomate rojo (jitomate)"
]

# Filtrar el DataFrame para incluir solo las filas con los cultivos de interés
chiapas_filtrado = cierre_agricola[cierre_agricola['Nomcultivo'].isin(cultivos_interes)]

# Seleccionar solo las columnas 'Año', 'Nomcultivo' y 'Rendimiento'
chiapas_seleccionado = chiapas_filtrado[['Año', 'Nomcultivo', 'Rendimiento']]

# Mostrar el resultado
print(chiapas_seleccionado)
# Out:
#         Año              Nomcultivo  Rendimiento
# 11     2003                  Papaya        25.00
# 29     2003                  Papaya        31.79
# 129    2003  Tomate rojo (jitomate)        20.00
# 141    2003                  Papaya        19.00
# 146    2003  Tomate rojo (jitomate)        20.00
# ...     ...                     ...          ...
# 21972  2023          Caña de azúcar        83.22
# 21997  2023                  Papaya        80.22
# 22001  2023          Caña de azúcar        91.10
# 22031  2023  Palma camedor (gruesa)       618.75
# 22053  2023  Tomate rojo (jitomate)        19.26
#
# [981 rows x 3 columns]

# %%
# Definir la lista de cultivos de interés
cultivos_interes = [
    "Crisantemo (gruesa)",
    "Lilium (gruesa)"
]

# Filtrar el DataFrame para incluir solo las filas con los cultivos de interés
chiapas_filtrado = cierre_agricola[cierre_agricola['Nomcultivo'].isin(cultivos_interes)]

# Seleccionar solo las columnas 'Año', 'Nomcultivo' y 'Rendimiento'
chiapas_seleccionado = chiapas_filtrado[['Año', 'Nomcultivo', 'Rendimiento']]

# Mostrar el resultado
print(chiapas_seleccionado)
# Out:
#         Año           Nomcultivo  Rendimiento
# 19055  2021  Crisantemo (gruesa)      2817.00
# 19056  2021      Lilium (gruesa)      2123.00
# 20079  2022  Crisantemo (gruesa)      2818.30
# 20080  2022      Lilium (gruesa)      2125.00
# 21222  2023  Crisantemo (gruesa)      2959.22
# 21223  2023      Lilium (gruesa)      2231.25

# %% [markdown]
# ## Analisis economico

# %%
# Agrupar los datos por cultivo y calcular la suma del valor de producción
rentabilidad_por_cultivo = cierre_agricola.groupby('Nomcultivo').agg({
    'Valorproduccion': 'sum'
}).reset_index()

# Ordenar los cultivos por valor de producción (rentabilidad)
cultivos_mas_rentables = rentabilidad_por_cultivo.sort_values(by='Valorproduccion', ascending=False)

# Mostrar los cultivos más rentables
print("Cultivos más rentables en términos de valor económico:")
print(cultivos_mas_rentables.head(10))
# Out:
# Cultivos más rentables en términos de valor económico:
#                     Nomcultivo  Valorproduccion
# 38                  Maíz grano     9.564906e+10
# 47           Pastos y praderas     4.464429e+10
# 5                  Café cereza     4.218504e+10
# 8               Caña de azúcar     3.491776e+10
# 54                     Plátano     3.479571e+10
# 34                       Mango     1.876357e+10
# 20                      Frijol     1.610367e+10
# 46                      Papaya     1.273960e+10
# 42  Palma africana o de aceite     1.039010e+10
# 67      Tomate rojo (jitomate)     8.498005e+09

# %%
# Si aún no se ha hecho, determinar los cultivos más rentables
cultivos_mas_rentables = cierre_agricola.groupby('Nomcultivo').agg({
    'Valorproduccion': 'sum'
}).reset_index().sort_values(by='Valorproduccion', ascending=False)

# Seleccionar los 5 cultivos más rentables para el análisis
cultivos_top = cultivos_mas_rentables.head(5)['Nomcultivo'].tolist()

# %%
# Filtrar el DataFrame para incluir solo los principales cultivos
chiapas_filtrado = cierre_agricola[cierre_agricola['Nomcultivo'].isin(cultivos_top)]

# Agrupar por cultivo y año, calculando el precio promedio
precio_por_cultivo_ano = chiapas_filtrado.groupby(['Nomcultivo', 'Año']).agg({
    'Precio': 'mean'
}).reset_index()

# %%
# Graficar la tendencia de los precios a lo largo del tiempo para los cultivos seleccionados
plt.figure(figsize=(14, 7))
for cultivo in cultivos_top:
    data_cultivo = precio_por_cultivo_ano[precio_por_cultivo_ano['Nomcultivo'] == cultivo]
    plt.plot(data_cultivo['Año'], data_cultivo['Precio'], marker='o', label=cultivo)

plt.title('Evolución de Precios de los Principales Cultivos (2003-2023)')
plt.xlabel('Año')
plt.ylabel('Precio Promedio (Pesos por Tonelada)')
plt.legend(title="Cultivo")
plt.grid(True)
plt.show()

# %%
cultivos_top
# Out:
# ['Maíz grano', 'Pastos y praderas', 'Café cereza', 'Caña de azúcar', 'Plátano']

# %%
# Filtrar el DataFrame para incluir solo las filas con los cultivos de interés
chiapas_filtrado = cierre_agricola[cierre_agricola['Nomcultivo'].isin(cultivos_top)]

# Seleccionar las columnas
chiapas_seleccionado = chiapas_filtrado[['Año', 'Nomcultivo', 'Rendimiento', 'Valorproduccion', 'Precio']]

# Mostrar el resultado
print(chiapas_seleccionado)
# Out:
#         Año   Nomcultivo  Rendimiento  Valorproduccion   Precio
# 0      2003   Maíz grano         2.50       1036750.00  1450.00
# 4      2003   Maíz grano         2.66      69908020.00  1420.00
# 13     2003   Maíz grano         1.18       6282080.00  1420.00
# 14     2003  Café cereza         1.65        914760.00  1800.00
# 17     2003      Plátano         6.70         87100.00  1300.00
# ...     ...          ...          ...              ...      ...
# 22086  2023   Maíz grano         1.03      10964190.95  4807.97
# 22089  2023   Maíz grano         1.15      26777389.54  4966.87
# 22094  2023   Maíz grano         0.88       9382394.98  4899.73
# 22096  2023   Maíz grano         1.14      38658918.30  4931.84
# 22097  2023  Café cereza         1.50      13470167.73  5429.33
#
# [7860 rows x 5 columns]

# %% [markdown]
# ### Siniestros

# %%
# Agrupar los datos por cultivo y calcular la suma de la superficie siniestrada
siniestros_por_cultivo = cierre_agricola.groupby('Nomcultivo').agg({
    'Siniestrada': 'sum'
}).reset_index()

# Ordenar los cultivos por superficie siniestrada
cultivos_mas_afectados = siniestros_por_cultivo.sort_values(by='Siniestrada', ascending=False)

# Mostrar los cultivos más afectados
print("Cultivos más afectados por siniestros:")
print(cultivos_mas_afectados.head(10))
# Out:
# Cultivos más afectados por siniestros:
#                 Nomcultivo  Siniestrada
# 38              Maíz grano    260678.79
# 20                  Frijol     16897.81
# 62                    Soya     14213.41
# 1                 Ajonjolí      5946.50
# 61             Sorgo grano      3876.00
# 56                  Sandía      1898.00
# 3                Cacahuate      1189.51
# 67  Tomate rojo (jitomate)       389.00
# 13             Chile verde       108.50
# 12              Chile seco        90.50

# %%
# Agrupar los datos por municipio y calcular la suma de la superficie siniestrada
siniestros_por_municipio = cierre_agricola.groupby('Nommunicipio').agg({
    'Siniestrada': 'sum'
}).reset_index()

# Ordenar los municipios por superficie siniestrada
municipios_mas_afectados = siniestros_por_municipio.sort_values(by='Siniestrada', ascending=False)

# Mostrar los municipios más afectados
print("Municipios más afectados por siniestros:")
print(municipios_mas_afectados.head(10))
# Out:
# Municipios más afectados por siniestros:
#              Nommunicipio  Siniestrada
# 56          La Trinitaria     18407.50
# 64                Mazatán     16241.85
# 118   Venustiano Carranza     13950.00
# 103             Tapachula     13706.91
# 30   Comitán de Domínguez     13253.25
# 121           Villaflores     12734.50
# 23        Chiapa de Corzo     12369.39
# 120           Villa Corzo     12132.25
# 17               Catazajá     11023.75
# 1                   Acala     10141.36

# %%
# Graficar los cultivos más afectados por siniestros
plt.figure(figsize=(10, 6))
plt.barh(cultivos_mas_afectados['Nomcultivo'].head(10), cultivos_mas_afectados['Siniestrada'].head(10), color='red')
plt.xlabel('Superficie Siniestrada (Hectáreas)')
plt.title('Top 10 Cultivos más Afectados por Siniestros')
plt.gca().invert_yaxis()
plt.show()

# Graficar los municipios más afectados por siniestros
plt.figure(figsize=(10, 6))
plt.barh(municipios_mas_afectados['Nommunicipio'].head(10), municipios_mas_afectados['Siniestrada'].head(10), color='orange')
plt.xlabel('Superficie Siniestrada (Hectáreas)')
plt.title('Top 10 Municipios más Afectados por Siniestros')
plt.gca().invert_yaxis()
plt.show()

# %%
# Agrupar los datos por año y cultivo para sumar la superficie siniestrada
siniestros_por_anio_cultivo = cierre_agricola.groupby(['Año', 'Nomcultivo']).agg({
    'Siniestrada': 'sum'
}).reset_index()

# Visualizar los primeros registros
print(siniestros_por_anio_cultivo.head())
# Out:
#     Año   Nomcultivo  Siniestrada
# 0  2003     Aguacate         0.00
# 1  2003     Ajonjolí         0.00
# 2  2003  Arroz palay        45.00
# 3  2003    Cacahuate         1.01
# 4  2003        Cacao         0.00

# %%
# Agrupar los datos por año y municipio para sumar la superficie siniestrada
siniestros_por_anio_municipio = cierre_agricola.groupby(['Año', 'Nommunicipio']).agg({
    'Siniestrada': 'sum'
}).reset_index()

# Visualizar los primeros registros
print(siniestros_por_anio_municipio.head())
# Out:
#     Año               Nommunicipio  Siniestrada
# 0  2003                 Acacoyagua          0.0
# 1  2003                      Acala          0.0
# 2  2003                 Acapetahua        132.5
# 3  2003                 Altamirano          0.0
# 4  2003  Amatenango de La Frontera          6.0

# %%
# Filtrar para los cultivos principales (opcional)
cultivos_principales = ['Caña de azúcar', 'Maíz', 'Tomate']  # Cambia según tus cultivos de interés
siniestros_filtrado = siniestros_por_anio_cultivo[siniestros_por_anio_cultivo['Nomcultivo'].isin(cultivos_principales)]

# Graficar la evolución de siniestros por cultivo a lo largo del tiempo
plt.figure(figsize=(14, 7))
for cultivo in cultivos_principales:
    data_cultivo = siniestros_filtrado[siniestros_filtrado['Nomcultivo'] == cultivo]
    plt.plot(data_cultivo['Año'], data_cultivo['Siniestrada'], marker='o', label=cultivo)

plt.title('Evolución de Siniestros por Cultivo (2003-2023)')
plt.xlabel('Año')
plt.ylabel('Superficie Siniestrada (Hectáreas)')
plt.legend(title="Cultivo")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Gráficos por cultivo

# %% [markdown]
# Filtración de los datos por cultivo

# %%
# Filtrar los datos para el cultivo
maiz = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Maíz grano']
cana_azucar = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Caña de azúcar']
cafe_cereza = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Café cereza']
platano = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Plátano']
mango = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Mango']
frijol = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Frijol']
papaya = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Papaya']
semilla_soya = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Semilla de soya']
tomate_rojo = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Tomate rojo (jitomate)']
cacao = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Cacao']
aguacate = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Aguacate']
papa = cierre_agricola[cierre_agricola['Nomcultivo'] == 'Papa']

# %% [markdown]
# Agrupación según area sembrada, cosechada, volumen y valor total de producción

# %%
# Agrupar por año y calcular las áreas totales sembradas, cosechadas y el volumen total de producción.
maiz_grouped = maiz.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
cana_azucar_grouped = cana_azucar.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
cafe_cereza_grouped = cafe_cereza.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
platano_grouped = platano.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
mango_grouped = mango.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
frijol_grouped = frijol.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
papaya_grouped = papaya.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
semilla_soya_grouped = semilla_soya.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
tomate_rojo_grouped = tomate_rojo.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
cacao_grouped = cacao.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
aguacate_grouped = aguacate.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()
papa_grouped = papa.groupby('Año', as_index=False)[['Sembrada', 'Cosechada', 'Volumenproduccion', 'Valorproduccion']].sum()

# %% [markdown]
# ### Grafico Maiz

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
maiz_grouped['Valorproduccion_miles'] = maiz_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=maiz_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=maiz_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=maiz_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=maiz_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción del Maíz Grano en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(maiz_grouped['Año'].min()), int(maiz_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Caña de azucar

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
cana_azucar_grouped['Valorproduccion_miles'] = cana_azucar_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=cana_azucar_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=cana_azucar_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=cana_azucar_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=cana_azucar_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción de la Caña de Azúcar en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(cana_azucar_grouped['Año'].min()), int(cana_azucar_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Café cereza

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
cafe_cereza_grouped['Valorproduccion_miles'] = cafe_cereza_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=cafe_cereza_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=cafe_cereza_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=cafe_cereza_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=cafe_cereza_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción del Café Cereza en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(cafe_cereza_grouped['Año'].min()), int(cafe_cereza_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Plátano

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
platano_grouped['Valorproduccion_miles'] = platano_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=platano_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=platano_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=platano_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=platano_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor del Plátano en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(platano_grouped['Año'].min()), int(platano_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Mango

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
mango_grouped['Valorproduccion_miles'] = mango_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=mango_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=mango_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=mango_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=mango_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción del Mango en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(mango_grouped['Año'].min()), int(mango_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Frijol

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
frijol_grouped['Valorproduccion_miles'] = frijol_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=frijol_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=frijol_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=frijol_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=frijol_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción del Frijol en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(frijol_grouped['Año'].min()), int(frijol_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Papaya

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
papaya_grouped['Valorproduccion_miles'] = papaya_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=papaya_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=papaya_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=papaya_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=papaya_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción de la Papaya en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(papaya_grouped['Año'].min()), int(papaya_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Semilla de Soya

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
semilla_soya_grouped['Valorproduccion_miles'] = semilla_soya_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=semilla_soya_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=semilla_soya_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=semilla_soya_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=semilla_soya_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción de la Semilla de Soya en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(semilla_soya_grouped['Año'].min()), int(semilla_soya_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Tomate rojo (jitomate)

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
tomate_rojo_grouped['Valorproduccion_miles'] = tomate_rojo_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=tomate_rojo_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=tomate_rojo_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=tomate_rojo_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=tomate_rojo_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción del Tomate Rojo (Jitomate) en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(tomate_rojo_grouped['Año'].min()), int(tomate_rojo_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfico Cacao

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
cacao_grouped['Valorproduccion_miles'] = cacao_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=cacao_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=cacao_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=cacao_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=cacao_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción del Cacao en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(cacao_grouped['Año'].min()), int(cacao_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Gráfica Papa

# %%
# Crear una nueva columna con los valores de producción divididos por 1000
papa_grouped['Valorproduccion_miles'] = papa_grouped['Valorproduccion'] / 1000

# Configurar el estilo de Seaborn
sns.set_style('whitegrid')

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=papa_grouped, x='Año', y='Sembrada', marker='o', label='Superficie Sembrada')
sns.lineplot(data=papa_grouped, x='Año', y='Cosechada', marker='o', label='Superficie Cosechada')
sns.lineplot(data=papa_grouped, x='Año', y='Volumenproduccion', marker='o', label='Volumen de Producción', linestyle='--')
sns.lineplot(data=papa_grouped, x='Año', y='Valorproduccion_miles', marker='o', label='Valor de Producción', linestyle='--')

# Personalizar el gráfico
plt.title('Volumen y Valor de Producción de la Papa en Chiapas')
plt.xlabel('Año')
plt.ylabel('Superficie (hectáreas) / Volumen (toneladas) / Valor (miles de pesos)')
plt.legend()

# Asegurarse de que los años en el eje x aparezcan como enteros
plt.xticks(ticks=range(int(papa_grouped['Año'].min()), int(papa_grouped['Año'].max()) + 2, 2))

# Mostrar el gráfico
plt.show()
